# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
LABELS = ["Legal", "Fraud"]

# %%
data=pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 83274  59766 -0.465927  0.740705  1.731343  0.036013  0.098876  0.055606
# 83275  59767 -0.725577  0.379742  1.468039  1.356958  0.546077  0.109718
# 83276  59768 -1.711347  1.308095 -0.232786 -1.607585 -1.299910 -0.627938
# 83277  59768  1.471591 -1.234024  0.279178 -1.595504 -1.344324 -0.101130
# 83278  59769  1.135220  0.124163  0.109082  0.902728  0.038998  0.004539
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 83274  0.472815  0.134921 -0.302919  ...  0.032294  0.287631 -0.337062
# 83275  0.416071  0.180774 -0.273686  ...  0.006224  0.017405 -0.101053
# 83276 -1.562053 -1.722859 -1.534618  ... -0.902970  1.269219  0.178712
# 83277 -1.249330  0.030445 -1.813220  ...  0.000785  0.310947 -0.194016
# 83278  0.007332  0.113029 -0.000000  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# 83274  0.079929  0.091760  0.396666  0.078020  0.093914    1.00    0.0
# 83275 -0.294967  0.164357 -0.166337  0.114452  0.115366   46.96    0.0
# 83276  0.527195 -0.313104 -0.365365  0.216308  0.181065   10.00    0.0
# 83277 -0.504003  0.513079  0.008417  0.029493  0.007596   40.00    0.0
# 83278       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83279 entries, 0 to 83278
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    83279 non-null  int64
#  1   V1      83279 non-null  float64
#  2   V2      83279 non-null  float64
#  3   V3      83279 non-null  float64
#  4   V4      83279 non-null  float64
#  5   V5      83279 non-null  float64
#  6   V6      83279 non-null  float64
#  7   V7      83279 non-null  float64
#  8   V8      83279 non-null  float64
#  9   V9      83279 non-null  float64
#  10  V10     83278 non-null  float64
#  11  V11     83278 non-null  float64
#  12  V12     83278 non-null  float64
#  13  V13     83278 non-null  float64
#  14  V14     83278 non-null  float64
#  15  V15     83278 non-null  float64
#  16  V16     83278 non-null  float64
#  17  V17     83278 non-null  float64
#  18  V18     83278 non-null  float64
#  19  V19     83278 non-null  float64
#  20  V20     83278 non-null  float64
#  21  V21     83278 non-null  float64
#  22  V22     83278 non-null  float64
#  23  V23     83278 non-null  float64
#  24  V24     83278 non-null  float64
#  25  V25     83278 non-null  float64
#  26  V26     83278 non-null  float64
#  27  V27     83278 non-null  float64
#  28  V28     83278 non-null  float64
#  29  Amount  83278 non-null  float64
#  30  Class   83278 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 19.7 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
count_classes = pd.value_counts(data['Class'], sort = True)

count_classes.plot(kind = 'bar',color='y', rot=0)

plt.title("Transaction Class Distribution")

plt.xticks(range(2), LABELS)

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data['Class'].value_counts()
# Out:
# 0.0    83077
# 1.0      201
# Name: Class, dtype: int64

# %% [markdown]
# This data is highly unbalanced.
# 0->normal transaction
# 1->fraud transaction

# %% [markdown]
# Seperating data for analysis

# %%
legal=data[data.Class==0]
fraud=data[data.Class==1]

# %%
print(legal.shape)
print(fraud.shape)
# Out:
# (83077, 31)
# (201, 31)

# %% [markdown]
# Here we can see easily that our fraud  data is very small compared to legitimate data

# %%
legal.Amount.describe()
# Out:
# count    83077.000000
# mean        98.225733
# std        269.373860
# min          0.000000
# 25%          7.700000
# 50%         26.990000
# 75%         89.690000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     201.000000
# mean       99.628756
# std       228.739325
# min         0.000000
# 25%         1.000000
# 50%         7.520000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# We will compare values for both transaction

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    38197.037038 -0.246222 -0.050140  0.701375  0.151217 -0.266942
# 1.0    33751.094527 -6.422458  4.501157 -8.551463  5.131404 -4.655227
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.099627 -0.096799  0.046602 -0.009665  ...  0.041320 -0.031195
# 1.0   -1.986353 -6.786837  2.973793 -3.072795  ...  0.406912  0.758621
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.105015 -0.037331  0.008906  0.133892  0.025943  0.000316  0.001995
# 1.0   -0.159979 -0.228778 -0.089971  0.232553  0.091620  0.568499  0.052008
#
#           Amount
# Class
# 0.0    98.225733
# 1.0    99.628756
#
# [2 rows x 30 columns]

# %% [markdown]
# Now we will do under-sampling.
# We will build a sample dataset containing similar distribution of normal transaction and fraud transaction.

# %%
legal_sample=legal.sample(n=492)

# %% [markdown]
# We Shuffle the entire dataset using sample function and separate classes by filtering the dataframe.

# %% [markdown]
# Concatenating two dataframes

# %%
new_data=pd.concat([legal_sample,fraud],axis=0)

# %%
new_data.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 71274  54237  0.769262 -0.987486 -0.613189  0.406943  1.351240  4.083386
# 63139  50579  1.155177  0.245482  0.145923  0.882668  0.159399  0.030496
# 47585  43265  1.225457 -0.775091  0.555828 -0.310509 -1.234582 -0.501354
# 68562  53044 -1.934874  0.476575  1.177739  0.934000 -0.464243  0.585372
# 46561  42835  1.037269 -0.978677 -0.213675 -0.637695 -0.849336 -0.710986
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 71274 -0.828203  1.006004  0.556228  ...  0.212429  0.103836 -0.330575
# 63139  0.078386  0.045134 -0.325788  ...  0.098562  0.321528 -0.139775
# 47585 -0.559639 -0.025657 -0.419001  ... -0.553673 -1.045263  0.166774
# 68562 -0.579503  1.070683 -0.152663  ...  0.030542 -0.049286 -0.007988
# 46561 -0.004256 -0.177175 -1.282815  ... -0.672300 -2.002461  0.083075
#
#             V24       V25       V26       V27       V28  Amount  Class
# 71274  1.031877  0.579562 -0.252127  0.025905  0.069979  240.00    0.0
# 63139 -0.283176  0.638163 -0.298736  0.026227  0.006772   18.09    0.0
# 47585  0.419718  0.049071  0.919420 -0.040891  0.013315   48.47    0.0
# 68562 -1.013588  0.499959 -0.175722 -0.112117 -0.326835   35.60    0.0
# 46561 -0.045892 -0.084765  0.610053 -0.117989  0.025438  190.90    0.0
#
# [5 rows x 31 columns]

# %%
new_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 80760  58642 -0.451383  2.225147 -4.953050  4.342228 -3.656190 -0.020121
# 81186  58822 -4.384221  3.264665 -3.077158  3.403594 -1.938075 -1.221081
# 81609  59011 -2.326922 -3.348439 -3.513408  3.175060 -2.815137 -0.203363
# 82400  59385 -7.626924 -6.976420 -2.077911  3.416754  4.458758 -5.080408
# 83053  59669  0.326007  1.286638 -2.007181  2.419675 -1.532902 -1.432803
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 80760 -5.407554 -0.748436 -1.362198  ... -0.575924  0.495889  1.154128
# 81186 -3.310317 -1.111975 -1.977593  ...  2.076383 -0.990303 -0.330358
# 81609 -0.892144  0.333226 -0.802005  ...  1.226648 -0.695902 -1.478490
# 82400 -6.578948  1.760341 -0.599509  ...  1.224795 -0.656639 -0.330811
# 83053 -2.459530  0.617738 -1.125861  ...  0.556895  0.169776 -0.174357
#
#             V24       V25       V26       V27       V28   Amount  Class
# 80760 -0.016186 -2.079928 -0.554377  0.455179  0.001321   113.92    1.0
# 81186  0.158378  0.006351 -0.493860 -1.537652 -0.994022    45.64    1.0
# 81609 -0.061553  0.236155  0.531911  0.302324  0.536375  1389.56    1.0
# 82400 -0.078946  0.270306  0.431119  0.821381 -1.056088    18.98    1.0
# 83053  0.308061  0.710996 -0.231030  0.580495  0.300984     6.27    1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Now we can see it clearly that both the number of fraud and legal transaction are equal

# %%
count_classes = pd.value_counts(new_data['Class'], sort = True)

count_classes.plot(kind = 'bar',color='g', rot=0)

plt.title("Transaction Class Distribution")

plt.xticks(range(2), LABELS)

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
new_data['Class'].value_counts()
# Out:
# 0.0    492
# 1.0    201
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    38381.060976 -0.199644 -0.042209  0.712465  0.260791 -0.223660
# 1.0    33751.094527 -6.422458  4.501157 -8.551463  5.131404 -4.655227
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.123654 -0.136857 -0.027595 -0.004928  ...  0.037580 -0.088328
# 1.0   -1.986353 -6.786837  2.973793 -3.072795  ...  0.406912  0.758621
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.091654 -0.070119 -0.034892  0.165786  0.006932 -0.006660  0.018036
# 1.0   -0.159979 -0.228778 -0.089971  0.232553  0.091620  0.568499  0.052008
#
#           Amount
# Class
# 0.0    96.866220
# 1.0    99.628756
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting data into features and targets.

# %%
X=new_data.drop(columns='Class',axis=1)
Y=new_data['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 71274  54237  0.769262 -0.987486 -0.613189  0.406943  1.351240  4.083386
# 63139  50579  1.155177  0.245482  0.145923  0.882668  0.159399  0.030496
# 47585  43265  1.225457 -0.775091  0.555828 -0.310509 -1.234582 -0.501354
# 68562  53044 -1.934874  0.476575  1.177739  0.934000 -0.464243  0.585372
# 46561  42835  1.037269 -0.978677 -0.213675 -0.637695 -0.849336 -0.710986
# ...      ...       ...       ...       ...       ...       ...       ...
# 80760  58642 -0.451383  2.225147 -4.953050  4.342228 -3.656190 -0.020121
# 81186  58822 -4.384221  3.264665 -3.077158  3.403594 -1.938075 -1.221081
# 81609  59011 -2.326922 -3.348439 -3.513408  3.175060 -2.815137 -0.203363
# 82400  59385 -7.626924 -6.976420 -2.077911  3.416754  4.458758 -5.080408
# 83053  59669  0.326007  1.286638 -2.007181  2.419675 -1.532902 -1.432803
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 71274 -0.828203  1.006004  0.556228  ...  0.467589  0.212429  0.103836
# 63139  0.078386  0.045134 -0.325788  ... -0.098181  0.098562  0.321528
# 47585 -0.559639 -0.025657 -0.419001  ... -0.496895 -0.553673 -1.045263
# 68562 -0.579503  1.070683 -0.152663  ... -0.176089  0.030542 -0.049286
# 46561 -0.004256 -0.177175 -1.282815  ... -0.126078 -0.672300 -2.002461
# ...         ...       ...       ...  ...       ...       ...       ...
# 80760 -5.407554 -0.748436 -1.362198  ...  0.724381 -0.575924  0.495889
# 81186 -3.310317 -1.111975 -1.977593  ... -0.141533  2.076383 -0.990303
# 81609 -0.892144  0.333226 -0.802005  ...  3.209171  1.226648 -0.695902
# 82400 -6.578948  1.760341 -0.599509  ...  2.875260  1.224795 -0.656639
# 83053 -2.459530  0.617738 -1.125861  ...  0.222667  0.556895  0.169776
#
#             V23       V24       V25       V26       V27       V28   Amount
# 71274 -0.330575  1.031877  0.579562 -0.252127  0.025905  0.069979   240.00
# 63139 -0.139775 -0.283176  0.638163 -0.298736  0.026227  0.006772    18.09
# 47585  0.166774  0.419718  0.049071  0.919420 -0.040891  0.013315    48.47
# 68562 -0.007988 -1.013588  0.499959 -0.175722 -0.112117 -0.326835    35.60
# 46561  0.083075 -0.045892 -0.084765  0.610053 -0.117989  0.025438   190.90
# ...         ...       ...       ...       ...       ...       ...      ...
# 80760  1.154128 -0.016186 -2.079928 -0.554377  0.455179  0.001321   113.92
# 81186 -0.330358  0.158378  0.006351 -0.493860 -1.537652 -0.994022    45.64
# 81609 -1.478490 -0.061553  0.236155  0.531911  0.302324  0.536375  1389.56
# 82400 -0.330811 -0.078946  0.270306  0.431119  0.821381 -1.056088    18.98
# 83053 -0.174357  0.308061  0.710996 -0.231030  0.580495  0.300984     6.27
#
# [693 rows x 30 columns]

# %%
print(Y)
# Out:
# 71274    0.0
# 63139    0.0
# 47585    0.0
# 68562    0.0
# 46561    0.0
#         ...
# 80760    1.0
# 81186    1.0
# 81609    1.0
# 82400    1.0
# 83053    1.0
# Name: Class, Length: 693, dtype: float64

# %% [markdown]
# Split the data into training set and testing set data.

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (693, 30) (554, 30) (139, 30)

# %% [markdown]
# Model training--->>>
# LOGISTIC REGRESSION

# %%
model=LogisticRegression(max_iter=100)

# %% [markdown]
# Training the Logistic Regression model with the traing data .

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %% [markdown]
# Now we will find the performance of the model by checking the accuracy score.

# %% [markdown]
# ACCURACY SCORE OF TRAINING DATA

# %%
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('ACCURACY ON TRAINING DATA:',training_data_accuracy)
# Out:
# ACCURACY ON TRAINING DATA: 0.9620938628158845

# %% [markdown]
# ACCURACY SCORE OF TEST DATA

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('ACCURACY ON TESTING DATA:',test_data_accuracy)
# Out:
# ACCURACY ON TESTING DATA: 0.9424460431654677
